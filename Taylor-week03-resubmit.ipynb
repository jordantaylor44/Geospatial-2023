# %% [markdown]
# # Jordan Taylor
# # Week 3 Homework

# %% [markdown]
# # Problem 2.4

# %%
station_numbers = []

# %%
for i in range(0,21,1):
    station_number=f"Station_{i}.txt"
    station_numbers.append(station_number)
print(station_numbers)
# Out:
# ['Station_0.txt', 'Station_1.txt', 'Station_2.txt', 'Station_3.txt', 'Station_4.txt', 'Station_5.txt', 'Station_6.txt', 'Station_7.txt', 'Station_8.txt', 'Station_9.txt', 'Station_10.txt', 'Station_11.txt', 'Station_12.txt', 'Station_13.txt', 'Station_14.txt', 'Station_15.txt', 'Station_16.txt', 'Station_17.txt', 'Station_18.txt', 'Station_19.txt', 'Station_20.txt']

# %% [markdown]
# # Problem 2.5

# %%
templist = [-5.4, 1.0, -1.3, -4.8, 3.9, 0.1, -4.4, 4.0, -2.2, -3.9, 4.4,
                -2.5, -4.6, 5.1, 2.1, -2.4, 1.9, -3.3, -4.8, 1.0, -0.8, -2.8,
                -0.1, -4.7, -5.6, 2.6, -2.7, -4.6, 3.4, -0.4, -0.9, 3.1, 2.4,
                1.6, 4.2, 3.5, 2.6, 3.1, 2.2, 1.8, 3.3, 1.6, 1.5, 4.7, 4.0,
                3.6, 4.9, 4.8, 5.3, 5.6, 4.1, 3.7, 7.6, 6.9, 5.1, 6.4, 3.8,
                4.0, 8.6, 4.1, 1.4, 8.9, 3.0, 1.6, 8.5, 4.7, 6.6, 8.1, 4.5,
                4.8, 11.3, 4.7, 5.2, 11.5, 6.2, 2.9, 4.3, 2.8, 2.8, 6.3, 2.6,
                -0.0, 7.3, 3.4, 4.7, 9.3, 6.4, 5.4, 7.6, 5.2]

# %%
cold = []
slippery = []
comfortable = []
warm = []

# %%
# how can I add counts to each if statement using the empty lists above?
# instead of manually counting?

for temp in templist:
    if temp < -2:
        print(temp, '= cold')
    if temp >= -2 and temp < 2:
        print(temp, '= slippery')
    if temp >= 2:
        print(temp, '= warm')
    if temp >= 2 and temp < 15:
        print (temp, '= comfortable & warm')
# Out:
# -5.4 = cold
# 1.0 = slippery
# -1.3 = slippery
# -4.8 = cold
# 3.9 = warm
# 3.9 = comfortable & warm
# 0.1 = slippery
# -4.4 = cold
# 4.0 = warm
# 4.0 = comfortable & warm
# -2.2 = cold
# -3.9 = cold
# 4.4 = warm
# 4.4 = comfortable & warm
# -2.5 = cold
# -4.6 = cold
# 5.1 = warm
# 5.1 = comfortable & warm
# 2.1 = warm
# 2.1 = comfortable & warm
# -2.4 = cold
# 1.9 = slippery
# -3.3 = cold
# -4.8 = cold
# 1.0 = slippery
# -0.8 = slippery
# -2.8 = cold
# -0.1 = slippery
# -4.7 = cold
# -5.6 = cold
# 2.6 = warm
# 2.6 = comfortable & warm
# -2.7 = cold
# -4.6 = cold
# 3.4 = warm
# 3.4 = comfortable & warm
# -0.4 = slippery
# -0.9 = slippery
# 3.1 = warm
# 3.1 = comfortable & warm
# 2.4 = warm
# 2.4 = comfortable & warm
# 1.6 = slippery
# 4.2 = warm
# 4.2 = comfortable & warm
# 3.5 = warm
# 3.5 = comfortable & warm
# 2.6 = warm
# 2.6 = comfortable & warm
# 3.1 = warm
# 3.1 = comfortable & warm
# 2.2 = warm
# 2.2 = comfortable & warm
# 1.8 = slippery
# 3.3 = warm
# ...

# %% [markdown]
# **Answers:**
#
# * Cold = 15 days
#
# * Comfortable/warm = 59 days
#
# * Warm = 59 days

# %% [markdown]
# # Problem 2.6

# %%
temp_f = 32
temp_celsius = (temp_f - 32) * (5/9)
temp_celsius
# Out:
# 0.0

# %%
temp_f = 68
temp_celsius = (temp_f - 32) * (5/9)
temp_celsius
# Out:
# 20.0

# %%
temp_f = 91
temp_celsius = (temp_f - 32) * (5/9)
temp_celsius
# Out:
# 32.77777777777778

# %%
temp_f = -17
temp_celsius = (temp_f - 32) * (5/9)
temp_celsius
# Out:
# -27.222222222222225

# %% [markdown]
# # Problem 2.7

# %%
temp_list2 = [17, 2, 1.9, -2]

for temp in temp_list2:
    if temp < -2:
        print(0)
    elif temp >= -2 and temp < 2:
        print(1)
    elif temp >= 2 and temp < 15:
        print(2)
    else:
        print(3)
# Out:
# 3
# 2
# 1
# 1

# %% [markdown]
# # Problem 3.1

# %% [markdown]
# ## Problem 1

# %%
import pandas as pd

# %%
data = pd.read_csv('6153237444115dat.csv')

# %%
data
# Out:
#         USAF   WBAN  YR--MODAHRMN  DIR SPD  GUS  CLG  SKC  L  M  ...     SLP  \
# 0      28450  99999  201705010000  174  10   14  ***  ***  *  *  ...  1009.2
# 1      28450  99999  201705010020  180  10  ***    4  ***  *  *  ...  ******
# 2      28450  99999  201705010050  190  10  ***    4  ***  *  *  ...  ******
# 3      28450  99999  201705010100  188  12   16  ***  ***  *  *  ...  1009.1
# 4      28450  99999  201705010120  200  13  ***    2  OBS  *  *  ...  ******
# ...      ...    ...           ...  ...  ..  ...  ...  ... .. ..  ...     ...
# 11689  29980  99999  201708311900  144  12   20   50  BKN  *  *  ...  1007.7
# 11690  29980  99999  201708312000  137  14   20   40  BKN  *  *  ...  1006.9
# 11691  29980  99999  201708312100  160  13  ***  ***  BKN  *  *  ...  1006.1
# 11692  29980  99999  201708312200  170  12   21   28  OVC  *  *  ...  1006.1
# 11693  29980  99999  201708312300  192  13   21   19  BKN  *  *  ...  1005.8
#
# ...

# %%
data.shape
# Out:
# (486, 33)

# %% [markdown]
# ## Problem 2
# 1. 11694 rows
# 2. column names include USAF, WBAN, YR--MODAHRMN, DIR, SPD, etc.
# 3. data types include integer (int64) and object

# %%
#removing non-numeric rows from the data set

data= data[pd.to_numeric(data['TEMP'], errors='coerce').notnull()]

data= data[pd.to_numeric(data['MAX'], errors='coerce').notnull()]

data.shape

data = data.dropna()

# %%
#converting to float

data['TEMP'] = pd.to_numeric(data['TEMP'])
data['MAX'] = pd.to_numeric(data['MAX'])

# %%
data['TEMP'].mean()
# Out:
# 54.37448559670782

# %%
data['MAX'].std()
# Out:
# 10.307989094641968

# %%
data["USAF"].unique()
# Out:
# array([28450, 29980])

# %%
data["USAF"].nunique()
# Out:
# 2

# %% [markdown]
# ## Problem 3

# %% [markdown]
# * Mean temperature = 54.37
# * Stdev of max column = 10.31
# * Unique stations = 2

# %% [markdown]
# # Problem 3.2

# %% [markdown]
# ## Problem 1

# %%
selected = pd.read_csv('6153237444115dat.csv', usecols=["USAF", "YR--MODAHRMN", "TEMP", "MAX", "MIN"])

# %%
selected['TEMP'].dropna()

#selected.dropna(how='all')

selected = selected.dropna()

# %%
selected
# Out:
#         USAF  YR--MODAHRMN TEMP  MAX  MIN
# 0      28450  201705010000   31  ***  ***
# 1      28450  201705010020   30  ***  ***
# 2      28450  201705010050   30  ***  ***
# 3      28450  201705010100   31  ***  ***
# 4      28450  201705010120   30  ***  ***
# ...      ...           ...  ...  ...  ...
# 11689  29980  201708311900   64  ***  ***
# 11690  29980  201708312000   64  ***  ***
# 11691  29980  201708312100   64  ***  ***
# 11692  29980  201708312200   64  ***  ***
# 11693  29980  201708312300   64  ***  ***
#
# [11694 rows x 5 columns]

# %%
temp = selected.loc[0:11694, ["TEMP"]]

# %%
check_columns = ["TEMP"]
clean_columns = temp.dropna(subset = check_columns)
clean_columns
# Out:
#       TEMP
# 0       31
# 1       30
# 2       30
# 3       31
# 4       30
# ...    ...
# 11689   64
# 11690   64
# 11691   64
# 11692   64
# 11693   64
#
# [11694 rows x 1 columns]

# %% [markdown]
# ## Problem 2

# %%
selected["CELSIUS"] = 0

# %%
selected.head()
# Out:
#     USAF  YR--MODAHRMN TEMP  MAX  MIN  CELSIUS
# 0  28450  201705010000   31  ***  ***        0
# 1  28450  201705010020   30  ***  ***        0
# 2  28450  201705010050   30  ***  ***        0
# 3  28450  201705010100   31  ***  ***        0
# 4  28450  201705010120   30  ***  ***        0

# %%
selected['TEMP'] = selected['TEMP'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 selected['TEMP'] = selected['TEMP'].astype(float)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
tempF = selected["TEMP"]
tempC = (tempF - 32) / 1.8
data["CELSIUS"] = tempC
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/computation/expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
#
# ...

# %%
# attempting to convert all the TEMP strings to floats with .0
# but the rows with **** still are not removed

# %%
selected = data[['USAF', 'YR--MODAHRMN', 'TEMP', 'MAX', 'MIN', 'CELSIUS']]
selected
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 selected = data[['USAF', 'YR--MODAHRMN', 'TEMP', 'MAX', 'MIN', 'CELSIUS']]
#       2 selected
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
# ...

# %% [markdown]
# ## Problem 3

# %%
selected = pd.read_csv('6153237444115dat.csv')

# %%
data.head()
# Out:
#       USAF   WBAN  YR--MODAHRMN  DIR SPD GUS  CLG  SKC  L  M  ...     SLP  \
# 18   28450  99999  201705010600  216  11  18  ***  ***  *  *  ...  1011.0
# 54   28450  99999  201705011800  229  15  23  ***  ***  *  *  ...  1013.6
# 90   28450  99999  201705020600  286  16  25  722  SCT  *  *  ...  1016.9
# 126  28450  99999  201705021800  318  11  23  ***  ***  *  *  ...  1025.7
# 161  28450  99999  201705030600  324   9  15  ***  BKN  *  *  ...  1031.2
#
#        ALT     STP MAX MIN  PCP01  PCP06  PCP24  PCPXX  SD
# 18   *****   985.8  34  31  *****  *****  *****  *****  35
# 54   *****   988.9  44  30  *****  *****  *****  *****  34
# 90   *****   992.1  42  35  *****  *****  *****  *****  34
# 126  *****  1000.5  45  36  *****  *****  *****  *****  33
# 161  *****  1005.9  37  33  *****  *****  *****  *****  33
#
# [5 rows x 33 columns]

# %%
selected = data[['USAF', 'YR--MODAHRMN', 'TEMP', 'MAX', 'MIN', 'CELSIUS']]

# %%
selected
# Out:
#         USAF  YR--MODAHRMN  TEMP  MAX MIN  CELSIUS
# 18     28450  201705010600    31   34  31      0.0
# 54     28450  201705011800    42   44  30      0.0
# 90     28450  201705020600    41   42  35      0.0
# 126    28450  201705021800    37   45  36      0.0
# 161    28450  201705030600    37   37  33      0.0
# ...      ...           ...   ...  ...  ..      ...
# 11640  29980  201708291800    62   64  58      0.0
# 11652  29980  201708300600    60   62  59      0.0
# 11664  29980  201708301800    63   67  60      0.0
# 11676  29980  201708310600    61   63  59      0.0
# 11688  29980  201708311800    64   66  61      0.0
#
# [486 rows x 6 columns]

# %%
#first selection to export to .csv

selection_USAF_1 = [29980]
kumpula = selected.loc[selected["USAF"].isin(selection_USAF_1)]
kumpula
# Out:
#         USAF  YR--MODAHRMN  TEMP  MAX MIN  CELSIUS
# 8776   29980  201705010600    44   44  35      0.0
# 8788   29980  201705011800    48   54  43      0.0
# 8800   29980  201705020600    50   50  34      0.0
# 8812   29980  201705021800    53   61  49      0.0
# 8824   29980  201705030600    47   53  38      0.0
# ...      ...           ...   ...  ...  ..      ...
# 11640  29980  201708291800    62   64  58      0.0
# 11652  29980  201708300600    60   62  59      0.0
# 11664  29980  201708301800    63   67  60      0.0
# 11676  29980  201708310600    61   63  59      0.0
# 11688  29980  201708311800    64   66  61      0.0
#
# [243 rows x 6 columns]

# %%
kumpula.to_csv("Kumpula_temps_May_Aug_2017.csv", sep = ',', float_format='%.2f')

# %%
#second selection to export to .csv

selection_USAF_2 = [28450]
rovaniemi = selected.loc[selected["USAF"].isin(selection_USAF_2)]
rovaniemi
# Out:
#        USAF  YR--MODAHRMN  TEMP  MAX MIN  CELSIUS
# 18    28450  201705010600    31   34  31      0.0
# 54    28450  201705011800    42   44  30      0.0
# 90    28450  201705020600    41   42  35      0.0
# 126   28450  201705021800    37   45  36      0.0
# 161   28450  201705030600    37   37  33      0.0
# ...     ...           ...   ...  ...  ..      ...
# 8608  28450  201708291800    54   54  48      0.0
# 8644  28450  201708300600    50   54  50      0.0
# 8680  28450  201708301800    52   58  50      0.0
# 8716  28450  201708310600    51   52  47      0.0
# 8752  28450  201708311800    55   63  51      0.0
#
# [243 rows x 6 columns]

# %%
rovaniemi.to_csv("Rovaniemi_temps_May_Aug_2017.csv", sep = ',', float_format='%.2f')
